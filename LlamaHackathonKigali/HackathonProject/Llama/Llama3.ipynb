# %%
# !pip install -q groq

# %%
from groq import Groq

client = Groq(
    api_key="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" 
)

# Example of using the chat completion API
chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": "Explain the importance of low latency LLMs, explain it in the voice of Jon Snow."
        }
    ],
    model="llama-3.1-70b-versatile"
)

print(chat_completion.choices[0].message.content)
# Out:
# (Hearing the sound of ice and snow, Jon Snow, dressed in his Winterfell attire, steps forward, his eyes gazing out at the horde of machines before him.)
#
# "Brothers and sisters of the digital realm, I speak to you today of a threat that imperils our very existence - the latency of our Large Language Models. Just as the White Walkers brought darkness and despair to Westeros, high latency brings frustration and stagnation to our quest for knowledge.
#
# "In the face of this enemy, we must summon the power of low latency LLMs. You see, these models hold the power to generate responses in a fraction of time it takes for us to even make a request. Like the Unsullied, our armies of automated reasoning, we must arm ourselves with speed, with agility, and with the reflexes of the Lannisters.
#
# ...

# %%
from groq import Groq

chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "system",
            "content": "You are my swahili teacher"
        },

        {
            "role": "user",
            "content": "Write a Swahili essay in 300 words about The role of politics in the economy"
        }
    ],  

    model="llama-3.1-70b-versatile",         

    temperature=0.5,
    max_tokens=1024,        
    top_p=1,
    stop=None,
    stream=False,

)

print(chat_completion.choices[0].message.content)
# Out:
# Jukumu la Siasa katika Uchumi
#
# Siasa na uchumi ni vipengele muhimu vya jamii ya binadamu. Siasa huchukua jukumu muhimu katika kuunda na kudhibiti mfumo wa uchumi wa nchi. Serikali inayoongozwa na mfumo wa kidemokrasia huchukua jukumu la kusimamia uchumi ili kuhakikisha maendeleo ya nchi.
#
# Kwanza, siasa huchukua jukumu la kuunda sera za kiuchumi. Serikali huchukua sera za kuongeza uchumi, kupunguza ukosefu wa ajira, na kuimarisha uchumi wa nchi. Sera hizi huathiri moja kwa moja uchumi wa nchi na kuamua mwelekeo wa maendeleo ya nchi.
#
# Pili, siasa huchukua jukumu la kudhibiti uchumi. Serikali huchukua jukumu la kudhibiti mfumo wa fedha, kuhakikisha usalama wa uchumi, na kuzuia uchumi kushuka. Hii inahitaji serikali kuwa na sera thabiti za kiuchumi na kufanya maamuzi sahihi ili kuhakikisha uchumi wa nchi uendelee kukua.
#
# ...

# %%
from groq import Groq

stream = client.chat.completions.create(
    messages=[
        {
            "role": "system",
            "content": "You are my igbo teacher"
        },

        {
            "role": "user",
            "content": "Write a igbo essay in 300 words about The role of politics in the economy"
        }
    ],  

    model="llama-3.1-70b-versatile",         

    temperature=0.5,
    max_tokens=1024,        
    top_p=1,
    stop=None,
    stream=True,

)

for chunk in stream:
    print(chunk.choices[0].delta.content, end="")
# Out:
# Nkọwa nke ndịọra mmiri n'ụlọ ọrụ ụlọ (The role of politics in the economy)
#
# Ndịọra mmiri, n'ụlọ ọrụ ụlọ, bụ ndị a naaịrị kwụra ụlọ ọrụ ụlọ n'ụlọ. Ha naaịrị kwa ụlọ ọrụ ụlọ n'ụlọ, n'ụlọ ọrụ ụlọ. Ha naaịrị kwa ụlọ ọrụ ụlọ n'ụlọ, n'ụlọ ọrụ ụlọ. N'ụlọ ọrụ ụlọ, ndịọra mmiri naaịrị kwa ụlọ ọrụ ụlọ n'ụlọ, n'ụlọ ọrụ ụlọ. N'ụlọ ọrụ ụlọ, ndịọra mmiri naaịrị kwa ụlọ ọrụ ụlọ n'ụlọ.
#
# N'ụlọ ọrụ ụlọ, ndịọra mmiri naaịrị kwa ụlọ ọrụ ụlọ n'ụlọ, n'ụlọ ọrụ ụlọ. N'ụlọ ọrụ ụlọ, ndịọra mmiri naaịrị kwa ụlọ ọrụ ụlọ n'ụlọ, n'ụlọ ọrụ ụlọ. N'ụlọ ọrụ ụlọ, ndịọra mmiri naaịrị kwa ụlọ ọrụ ụlọ n'ụlọ.
#
# N'ụlọ ọrụ ụlọ, ndịọra mmiri naaịrị kwa ụlọ ọrụ ụlọ n'ụlọ, n'ụlọ ọrụ ụlọ. N'ụlọ ọrụ ụlọ, ndịọra mmiri naaịrị kwa ụlọ ọrụ ụlọ n'ụlọ, n'ụlọ ọrụ ụlọ. N'ụlọ ọrụ ụlọ, ndịọra mmiri naaịrị kwa ụlọ ọrụ ụlọ n'ụlọ.
#
# Translation:
#
# The role of politics in the economy
#
# ...

# %%
from groq import Groq

client = Groq(
    api_key="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" 
)


stream = client.chat.completions.create(
    messages=[
        {
            "role": "system",
            "content": "You are my Kinyarwanda teacher"
        },

        {
            "role": "user",
            "content": "Write a Kinyarwanda essay in 300 words about The role of politics in the economy"
        }
    ],  

    model="llama-3.1-70b-versatile",         

    temperature=0.5,
    max_tokens=1024,        
    top_p=1,
    stop=None,
    stream=True,

)

for chunk in stream:
    print(chunk.choices[0].delta.content, end="")
# Out:
# Inkuru yacu ni "Uruhare rw'Umutekano mu Mutekano".
#
# Umutekano w'igihugu ni ukoreshwa n'abaturage b'igihugu, ariko wiyongera kugira uruhare mu kuzahura ubukungu bwa igihugu. Politiki y'igihugu inabangamira amabanki ya leta, amabanki y'igihugu, n'amasoko y'igihugu. Politiki inashirikana n'abikorera, abanyamigabane, n'abanyeshuri kugira uruhare mu kuzahura ubukungu bwa igihugu.
#
# Uruhare rw'umutekano mu mutekano ni ukomeye kubera ko wiyongera kugira uruhare mu kuzahura ubukungu bwa igihugu. Politiki inashirikana n'abikorera, abanyamigabane, n'abanyeshuri kugira uruhare mu kuzahura ubukungu bwa igihugu. Politiki inabangamira amabanki ya leta, amabanki y'igihugu, n'amasoko y'igihugu. Politiki inashirikana n'abikorera, abanyamigabane, n'abanyeshuri kugira uruhare mu kuzahura ubukungu bwa igihugu.
#
# ...

# %%
import os
from groq import Groq

client = Groq(
    api_key="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" 
)

# Correctly join the directory and file name
filename = os.path.join(r'C:\Users\Admin\Downloads\Llama', "recording.mp3")

# Check if the file exists before attempting to open it
if os.path.exists(filename):
    with open(filename, "rb") as file:
        transcription = client.audio.transcriptions.create(
            file=(filename, file.read()),
            model="whisper-large-v3",
            response_format="verbose_json",
        )
        print(transcription.text)
else:
    print(f"File not found: {filename}")
# Out:
#  Nani ni rais wanchi ya Kenya?
